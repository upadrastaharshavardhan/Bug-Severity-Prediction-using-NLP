# %% [markdown]
# # Project 8 – Bug Severity Prediction
#
# Colab Quickstart

# %%
import os
os.chdir("/content/ai-bug-severity-prediction") if os.path.exists("/content/ai-bug-severity-prediction") else None
print(os.getcwd())

# %%
# !pip install -q -r requirements.txt

# %%
# !python scripts/generate_data.py --n-samples 4000
# !python scripts/train.py

# %%
from src.pipeline.predictor import SeverityPredictor
p = SeverityPredictor.load("artifacts")
print(p.predict(title="Production database completely down",
    description="Primary DB unreachable. All transactions failing."))
